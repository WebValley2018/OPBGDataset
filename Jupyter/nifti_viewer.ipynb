# %%
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

PATH = "/Users/riccardobusetti/Desktop/tmp_processed_nifti/registered_2.nii"

image = sitk.ReadImage(PATH)
image_np = sitk.GetArrayFromImage(image)
image_np = image_np[:, ::-1, :]

print(image_np.shape)

plt.imshow(image_np[10, :, :])
plt.show()
# Out:
# (35, 448, 322)

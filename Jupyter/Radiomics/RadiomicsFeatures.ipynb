# %%
from radiomics import featureextractor, glrlm
import os
import sys
import SimpleITK as sitk
import pandas as pd
import pprint
from multiprocessing import Manager, Lock, Pool, cpu_count
import time

# %%
def progress(count, total, status=''):
    
    bar_len = 40
    filled_len = int(round(bar_len * count / float(total)))

    percents = round(100.0 * count / float(total), 1)
    bar = '█' * filled_len + '░' * (bar_len - filled_len)

    sys.stdout.write(f'\r|{bar}| {percents}% ... {status}')
    sys.stdout.flush()

# %%
# Paths to scans' dir, survival csv file and output dir
DATADIR = '/path/to/file'
OUTDIR = '/path/to/file'
survival_data = '/path/to/file/.../brats/survival_data.csv'

# %%
# Path to extractor parameters and setup of extractor
params = '/path/to/file/my_params.yaml'
extractor = featureextractor.RadiomicsFeaturesExtractor(params)
# extractor = featureextractor.RadiomicsFeaturesExtractor()

# %%
# Display current setup for extractor (those could be changed by modifing my_params.yaml)
print('Extraction parameters:')
pprint.pprint(extractor.settings, indent=2)
print('\nEnabled filters:')
pprint.pprint(extractor._enabledImagetypes, indent=2)
print('\nEnabled features:')
pprint.pprint(extractor._enabledFeatures, indent=2)
# Out:
# Extraction parameters:
# { 'additionalInfo': True,
#   'binWidth': 25,
#   'distances': [1],
#   'force2D': False,
#   'force2Ddimension': 0,
#   'interpolator': 'sitkBSpline',
#   'label': 1,
#   'minimumROIDimensions': 1,
#   'minimumROISize': None,
#   'normalize': False,
#   'normalizeScale': 1,
#   'padDistance': 5,
#   'preCrop': False,
#   'removeOutliers': None,
#   'resampledPixelSpacing': None,
#   'resegmentRange': None,
#   'weightingNorm': None}
#
# Enabled filters:
# { 'Exponential': {},
#   'Gradient': {},
#   'LoG': {'sigma': [1.0, 3.0]},
#   'Logarithm': {},
#   'Original': {},
#   'Square': {},
#   'SquareRoot': {},
#   'Wavelet': {'binWidth': 30}}
#
# Enabled features:
# { 'firstorder': None,
#   'glcm': [ 'Autocorrelation',
#             'JointAverage',
#             'ClusterProminence',
#             'ClusterShade',
#             'ClusterTendency',
#             'Contrast',
#             'Correlation',
#             'DifferenceAverage',
#             'DifferenceEntropy',
#             'DifferenceVariance',
#             'JointEnergy',
#             'JointEntropy',
#             'Imc1',
#             'Imc2',
#             'Idm',
#             'Idmn',
#             'Id',
#             'Idn',
#             'InverseVariance',
#             'MaximumProbability',
#             'SumEntropy',
#             'SumSquares'],
#   'gldm': None,
#   'glrlm': None,
#   'glszm': None,
#   'shape': None}

# %%
# Gets all the samples and filters away other paths (if there's some non-BraTS file)
# Could change depending on which dataset you're working on
g_samples = [*filter(lambda x: x.startswith('Brats18'), os.listdir(DATADIR))]

# %%
# Loads survival csv with panda and gets array of names of samples in it
survival = pd.read_csv(survival_data)
sub_names = [*survival.BraTS18ID]

# %%
#Function to segment the array in order to utilize multiprocessing

def segment(array, parts):
    
    avg = len(array) / parts
    last = 0.0

    while last < len(array):
        yield array[int(last):int(last + avg)]
        last += avg

# %%
#Calculates the features of the brain scans
def calculate_feature(samples):
    
    for sample in samples:
    
        # Gets the row of the sample and gets age and survival.
        # If age or survival are not avaiable sets the values to None
        row = survival.loc[survival['BraTS18ID'] == sample]
        age = int(row['Age']) if len(row['Age']) else None
        surv = int(row['Survival']) if len(row['Survival']) else None

        # Reads the image with SimpleITK and applies Threshold function
        label = sitk.ReadImage(os.path.join(DATADIR, sample, f'{sample}_seg.nii.gz'))

        # Gets the features for every scan
        feature = {}
        for seq in ['t1', 't1ce', 't2', 'flair']:    #could change with OPBG
            image = sitk.ReadImage(os.path.join(DATADIR, sample, f'{sample}_{seq}.nii.gz'))
            result = extractor.execute(image, label)

            # Make an array of the values
            for key, value in result.items():
                if not key.startswith("general_"):
                    feature[key + f'_{seq}'] = result[key]

        # Adds age, survival and sample name to the feature list
        feature['age'] = age
        feature['surv'] = surv
        feature['sample'] = sample
        with Lock():
            features_man.append(feature)
            # Progress bar for better visualization
            count.value += 1
            progress(count.value, len(g_samples), status=f'Extracting Features ... {sample}')

# %%
with Manager() as manager:
    # List of all features
    features_man = manager.list()
    count = manager.Value('i', 0)
    
    t0 = time.time()

    with Pool(cpu_count()) as pool:
        tasks = [pool.apply_async(calculate_feature, args=(part,)) for part in segment(g_samples, cpu_count())]

        [task.get() for task in tasks]

        features_all = [x for x in features_man]

    print(f' ... {round(time.time() - t0, 2)}s')
# Out:
# |██████████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░| 25.3% ... Extracting Features ... Brats18_TCIA10_346_1
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: invalid value encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:359: RuntimeWarning: divide by zero encountered in true_divide
#   lglre = numpy.sum((pg / (ivector[:, None] ** 2)), 0) / Nz
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: divide by zero encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: invalid value encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: divide by zero encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: invalid value encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:314: RuntimeWarning: divide by zero encountered in true_divide
#   lie = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: divide by zero encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: invalid value encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: divide by zero encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: invalid value encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:300: RuntimeWarning: divide by zero encountered in true_divide
#   lgle = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: divide by zero encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: invalid value encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# |██████████████░░░░░░░░░░░░░░░░░░░░░░░░░░| 36.0% ... Extracting Features ... Brats18_TCIA10_629_1
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: invalid value encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:359: RuntimeWarning: divide by zero encountered in true_divide
#   lglre = numpy.sum((pg / (ivector[:, None] ** 2)), 0) / Nz
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: divide by zero encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: invalid value encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: divide by zero encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: invalid value encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:314: RuntimeWarning: divide by zero encountered in true_divide
#   lie = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: divide by zero encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: invalid value encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: divide by zero encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: invalid value encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:300: RuntimeWarning: divide by zero encountered in true_divide
#   lgle = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: divide by zero encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: invalid value encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# |█████████████████████████████████░░░░░░░| 82.7% ... Extracting Features ... Brats18_TCIA10_644_1
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:426: RuntimeWarning: invalid value encountered in true_divide
#   lrlgle = numpy.sum((self.P_glrlm * (jvector[None, :, None] ** 2) / (ivector[:, None, None] ** 2)),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:359: RuntimeWarning: divide by zero encountered in true_divide
#   lglre = numpy.sum((pg / (ivector[:, None] ** 2)), 0) / Nz
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: divide by zero encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glrlm.py:392: RuntimeWarning: invalid value encountered in true_divide
#   srlgle = numpy.sum((self.P_glrlm / ((ivector[:, None, None] ** 2) * (jvector[None, :, None] ** 2))),
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: divide by zero encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:382: RuntimeWarning: invalid value encountered in true_divide
#   lilae = numpy.sum(self.P_glszm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:314: RuntimeWarning: divide by zero encountered in true_divide
#   lie = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: divide by zero encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/glszm.py:348: RuntimeWarning: invalid value encountered in true_divide
#   lisae = numpy.sum(self.P_glszm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: divide by zero encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:377: RuntimeWarning: invalid value encountered in true_divide
#   ldlgle = numpy.sum(self.P_gldm * (jvector[None, :] ** 2) / (ivector[:, None] ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:300: RuntimeWarning: divide by zero encountered in true_divide
#   lgle = numpy.sum(pg / (ivector ** 2)) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: divide by zero encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# /home/group2/marco/pyradiomics/radiomics/gldm.py:339: RuntimeWarning: invalid value encountered in true_divide
#   sdlgle = numpy.sum(self.P_gldm / ((ivector[:, None] ** 2) * (jvector[None, :] ** 2))) / Nz
# |████████████████████████████████████████| 100.0% ... Extracting Features ... Brats18_TCIA10_637_1 ... 605.82s

# %%
# New dataframe for feature storing
df = pd.DataFrame()
t0 = time.time()

# Generation of csv file
for i, feature in enumerate(features_all):
    progress(i + 1, len(features_all), status='Writing features to disk')
    df = pd.concat([df, pd.DataFrame(feature, index=[i])])

print(f' ... {round(time.time() - t0, 2)}s')

# Saving the csv file to the specified path    
df.to_csv(os.path.join(OUTDIR, 'HGG_full.csv'))
# Out:
# |████████████████████████████████████████| 100.0% ... Writing features to disk ... 16.21s

# %%
df
# Out:
#     original_shape_Elongation_t1  original_shape_Flatness_t1  \
# 0                       0.859293                    0.472908
# 1                       0.866290                    0.501836
# 2                       0.755805                    0.598468
# 3                       0.807621                    0.600040
# 4                       0.828242                    0.621108
# 5                       0.720288                    0.575729
# 6                       0.823293                    0.651742
# 7                       0.702176                    0.605063
# 8                       0.841307                    0.634258
# 9                       0.849219                    0.701774
# 10                      0.753312                    0.644358
# 11                      0.634467                    0.483627
# 12                      0.820845                    0.648112
# 13                      0.675910                    0.574889
# 14                      0.745738                    0.724867
# 15                      0.824036                    0.773410
# 16                      0.725233                    0.678258
# 17                      0.703146                    0.458814
# 18                      0.906196                    0.722994
# 19                      0.789411                    0.683328
# 20                      0.918261                    0.608166
# 21                      0.544224                    0.435792
# 22                      0.534421                    0.424904
# 23                      0.853657                    0.534000
# 24                      0.941683                    0.764072
# 25                      0.884369                    0.753598
# 26                      0.633840                    0.431796
# 27                      0.763911                    0.566237
# 28                      0.819899                    0.770677
# 29                      0.826004                    0.749689
# ..                           ...                         ...
# 45                      0.620108                    0.392151
# 46                      0.854641                    0.664452
# 47                      0.861739                    0.739791
# 48                      0.825060                    0.615299
# 49                      0.889898                    0.754327
# 50                      0.803867                    0.726049
# 51                      0.719637                    0.676409
# 52                      0.716253                    0.532311
# 53                      0.856749                    0.638930
# 54                      0.590632                    0.427576
# 55                      0.694381                    0.424626
# 56                      0.663167                    0.623563
# 57                      0.883755                    0.699034
# 58                      0.841830                    0.668501
# 59                      0.653321                    0.455219
# 60                      0.826434                    0.535105
# 61                      0.922007                    0.657619
# 62                      0.727318                    0.665742
# 63                      0.849652                    0.646301
# 64                      0.853560                    0.750924
# 65                      0.861288                    0.601774
# 66                      0.958051                    0.731038
# 67                      0.770203                    0.574096
# 68                      0.756391                    0.572932
# 69                      0.945150                    0.643427
# 70                      0.839638                    0.793273
# 71                      0.697682                    0.471970
# 72                      0.801742                    0.622147
# 73                      0.607856                    0.500421
# 74                      0.790739                    0.662864
#
#     original_shape_LeastAxis_t1  original_shape_MajorAxis_t1  \
# 0                     10.934087                    23.120976
# 1                     13.434651                    26.771009
# 2                     16.574364                    27.694660
# 3                     15.748353                    26.245517
# 4                     24.436927                    39.344085
# 5                     27.343621                    47.493922
# 6                     29.098382                    44.647086
# 7                     35.280154                    58.308196
# 8                     30.833516                    48.613516
# 9                     12.873150                    18.343718
# 10                    37.575843                    58.315163
# 11                    31.481108                    65.093770
# 12                    39.012820                    60.194606
# 13                    39.058301                    67.940549
# 14                    40.292689                    55.586312
# 15                    21.551494                    27.865552
# 16                    44.739259                    65.962003
# 17                    32.204428                    70.190621
# 18                    41.819355                    57.841938
# 19                    24.594571                    35.992310
# 20                    14.256849                    23.442367
# 21                    38.881084                    89.219444
# 22                     7.149128                    16.825268
# 23                    16.323958                    30.569235
# 24                    20.707164                    27.101072
# 25                    50.212864                    66.630839
# 26                    14.664250                    33.961079
# 27                    23.183247                    40.942685
# 28                    40.141430                    52.085951
# 29                    54.432254                    72.606448
# ..                          ...                          ...
# 45                    26.537579                    67.671895
# 46                    54.842048                    82.537292
# 47                    42.284779                    57.157733
# 48                    41.274468                    67.080384
# 49                    24.624355                    32.644143
# 50                    51.567853                    71.025288
# 51                    35.871321                    53.032006
# 52                    32.468828                    60.996030
# 53                    35.445517                    55.476412
# 54                    16.262209                    38.033463
# 55                    16.878428                    39.748913
# 56                    11.387173                    18.261455
# 57                    30.827521                    44.100150
# 58                    23.847468                    35.673046
# 59                    21.643740                    47.545734
# 60                    37.287176                    69.681970
# 61                    39.503927                    60.071147
# 62                    29.852235                    44.840544
# 63                    45.685964                    70.688424
# 64                    54.127716                    72.081500
# 65                    19.535631                    32.463398
# 66                    45.151995                    61.764258
# 67                    46.119826                    80.334741
# 68                    41.502390                    72.438567
# 69                    47.513656                    73.844686
# 70                    28.890668                    36.419597
# 71                    41.568029                    88.073439
# 72                    39.140907                    62.912604
# 73                    35.030621                    70.002323
# 74                    45.443284                    68.555995
#
#     original_shape_Maximum2DDiameterColumn_t1  \
# 0                                   21.213203
# 1                                   37.735925
# 2                                   27.658633
# 3                                   28.160256
# 4                                   41.436699
# 5                                   41.109610
# 6                                   47.507894
# 7                                   51.623638
# 8                                   51.623638
# 9                                   17.464249
# 10                                  51.662365
# 11                                  49.819675
# 12                                  57.706152
# 13                                  56.612719
# 14                                  61.846584
# 15                                  26.419690
# 16                                  62.681736
# 17                                  62.241465
# 18                                  59.816386
# 19                                  34.205263
# 20                                  25.612497
# 21                                  63.702433
# 22                                  23.259407
# 23                                  33.541020
# 24                                  31.622777
# 25                                  73.246160
# 26                                  29.410882
# 27                                  37.643060
# 28                                  53.338541
# 29                                  76.321688
# ..                                        ...
# 45                                  58.898217
# 46                                  85.708809
# 47                                  58.821765
# 48                                  69.115845
# 49                                  34.234486
# 50                                  71.840100
# 51                                  69.584481
# 52                                  52.239832
# 53                                  64.070274
# 54                                  28.017851
# 55                                  28.653098
# 56                                  26.248809
# 57                                  49.648766
# 58                                  31.048349
# 59                                  36.138622
# 60                                  68.359345
# 61                                  71.344236
# 62                                  41.725292
# 63                                  74.632433
# 64                                  74.793048
# 65                                  34.481879
# 66                                  68.709534
# 67                                  81.841310
# 68                                  64.195015
# 69                                  83.186537
# 70                                  38.897301
# 71                                  74.330344
# 72                                  64.845971
# 73                                  55.470713
# 74                                  84.202138
#
#     original_shape_Maximum2DDiameterRow_t1  \
# 0                                28.844410
# 1                                28.284271
# 2                                47.095647
# 3                                28.792360
# 4                                44.721360
# 5                                59.682493
# 6                                55.072679
# 7                                46.529560
# 8                                55.803226
# 9                                18.867962
# 10                               65.604878
# 11                               78.447435
# 12                               88.588938
# 13                               80.056230
# 14                               65.368188
# 15                               26.400758
# 16                               71.805292
# 17                               79.705709
# 18                               69.231496
# 19                               39.395431
# 20                               27.294688
# 21                              105.304321
# 22                               22.472205
# 23                               36.069378
# 24                               31.827661
# 25                               76.896034
# 26                               22.825424
# 27                               44.922155
# 28                               65.459911
# 29                               82.000000
# ..                                     ...
# 45                               73.082146
# 46                               87.005747
# 47                               69.354164
# 48                               77.201036
# 49                               38.600518
# 50                               82.036577
# 51                               67.742158
# 52                               67.742158
# 53                               65.969690
# 54                               46.173586
# 55                               43.416587
# 56                               22.203603
# 57                               55.362442
# 58                               32.649655
# 59                               53.310412
# 60                               86.313383
# 61                               87.823687
# 62                               55.226805
# 63                               87.005747
# 64                               86.821656
# 65                               33.600595
# 66                               78.746428
# 67                              112.218537
# 68                               85.070559
# 69                               90.094395
# 70                               39.661064
# 71                               97.693398
# 72                               71.449283
# 73                               86.815897
# 74                               69.892775
#
#     original_shape_Maximum2DDiameterSlice_t1  \
# 0                                  19.235384
# 1                                  26.627054
# 2                                  49.497475
# 3                                  30.675723
# 4                                  37.947332
# 5                                  55.542776
# 6                                  45.221676
# 7                                  54.671748
# 8                                  49.497475
# 9                                  20.000000
# 10                                 61.351447
# 11                                 65.764732
# 12                                 70.178344
# 13                                 74.094534
# 14                                 55.731499
# 15                                 22.203603
# 16                                 75.894664
# 17                                 78.313473
# 18                                 68.963759
# 19                                 38.078866
# 20                                 25.019992
# 21                                103.174609
# 22                                  9.219544
# 23                                 39.293765
# 24                                 31.400637
# 25                                 77.201036
# 26                                 29.206164
# 27                                 44.922155
# 28                                 57.140179
# 29                                 83.006024
# ..                                       ...
# 45                                 73.061618
# 46                                 84.723078
# 47                                 69.065187
# 48                                 71.175839
# 49                                 36.769553
# 50                                 78.771822
# 51                                 46.238512
# 52                                 67.268120
# 53                                 64.381674
# 54                                 39.560081
# 55                                 43.566042
# 56                                 17.000000
# 57                                 49.769469
# 58                                 33.615473
# 59                                 49.365980
# 60                                 82.734515
# 61                                 75.106591
# 62                                 58.694122
# 63                                 76.791927
# 64                                 82.565126
# 65                                 37.483330
# 66                                 75.471849
# 67                                111.287915
# 68                                 81.221918
# 69                                 89.358827
# 70                                 39.357337
# 71                                 90.249654
# 72                                 79.378838
# 73                                 70.213959
# 74                                 80.653580
#
#     original_shape_Maximum3DDiameter_t1  original_shape_MinorAxis_t1  \
# 0                             32.939338                    19.867693
# 1                             41.593269                    23.191446
# 2                             50.685304                    20.931749
# 3                             31.192948                    21.196427
# 4                             46.195238                    32.586442
# 5                             61.204575                    34.209304
# 6                             56.692151                    36.757635
# 7                             56.780278                    40.942637
# 8                             56.169387                    40.898893
# 9                             20.346990                    15.577831
# 10                            69.785385                    43.929511
# 11                            78.676553                    41.299851
# 12                            88.611512                    49.410414
# 13                            80.864083                    45.921707
# 14                            66.053009                    41.452800
# 15                            29.899833                    22.962218
# 16                            76.902536                    47.837807
# 17                            81.547532                    49.354274
# 18                            71.630999                    52.416123
# 19                            40.373258                    28.412742
# 20                            27.964263                    21.526210
# 21                           105.621967                    48.555405
# 22                            26.400758                     8.991785
# 23                            39.749214                    26.095632
# 24                            33.301652                    25.520621
# 25                            78.492038                    58.926282
# 26                            35.440090                    21.525905
# 27                            47.169906                    31.276566
# 28                            65.467549                    42.705203
# 29                            83.701852                    59.973233
# ..                                  ...                          ...
# 45                            75.405570                    41.963879
# 46                           102.464628                    70.539774
# 47                            72.567210                    49.255053
# 48                            81.816869                    55.345323
# 49                            39.458839                    29.049965
# 50                            83.821238                    57.094890
# 51                            70.469852                    38.163781
# 52                            68.212902                    43.688612
# 53                            68.541958                    47.529341
# 54                            47.010637                    22.463790
# 55                            45.088801                    27.600895
# 56                            26.570661                    12.110393
# 57                            57.480431                    38.973727
# 58                            35.707142                    30.030643
# 59                            54.313902                    31.062631
# 60                            86.406018                    57.587533
# 61                            90.216406                    55.386019
# 62                            63.733821                    32.613343
# 63                            89.073004                    60.060591
# 64                            87.960218                    61.525865
# 65                            38.131352                    27.960334
# 66                            82.516665                    59.173310
# 67                           113.516519                    61.874074
# 68                            86.278618                    54.791867
# 69                            92.881645                    69.794336
# 70                            41.424630                    30.579290
# 71                           101.941159                    61.447249
# 72                            79.856121                    50.439690
# 73                            87.183714                    42.551308
# 74                            89.649317                    54.209925
#
#     original_shape_Sphericity_t1          ...           \
# 0                       0.296505          ...
# 1                       0.239142          ...
# 2                       0.441835          ...
# 3                       0.694198          ...
# 4                       0.674545          ...
# 5                       0.572253          ...
# 6                       0.687487          ...
# 7                       0.296694          ...
# 8                       0.765215          ...
# 9                       0.415493          ...
# 10                      0.469152          ...
# 11                      0.430987          ...
# 12                      0.621684          ...
# 13                      0.715755          ...
# 14                      0.572831          ...
# 15                      0.251300          ...
# 16                      0.631178          ...
# 17                      0.507590          ...
# 18                      0.666310          ...
# 19                      0.779882          ...
# 20                      0.736603          ...
# 21                      0.520293          ...
# 22                      0.500671          ...
# 23                      0.462355          ...
# 24                      0.653317          ...
# 25                      0.716034          ...
# 26                      0.258862          ...
# 27                      0.663018          ...
# 28                      0.775865          ...
# 29                      0.550141          ...
# ..                           ...          ...
# 45                      0.477640          ...
# 46                      0.189494          ...
# 47                      0.523264          ...
# 48                      0.563072          ...
# 49                      0.271354          ...
# 50                      0.622308          ...
# 51                      0.580283          ...
# 52                      0.492870          ...
# 53                      0.541929          ...
# 54                      0.715980          ...
# 55                      0.410562          ...
# 56                      0.465399          ...
# 57                      0.234703          ...
# 58                      0.211492          ...
# 59                      0.677308          ...
# 60                      0.519540          ...
# 61                      0.312812          ...
# 62                      0.588407          ...
# 63                      0.615106          ...
# 64                      0.414269          ...
# 65                      0.540238          ...
# 66                      0.515006          ...
# 67                      0.370616          ...
# 68                      0.229179          ...
# 69                      0.170172          ...
# 70                      0.813204          ...
# 71                      0.428001          ...
# 72                      0.658516          ...
# 73                      0.493917          ...
# 74                      0.326020          ...
#
#     gradient_gldm_LargeDependenceEmphasis_flair  \
# 0                                     93.709382
# 1                                     32.387075
# 2                                    299.918558
# 3                                    332.456719
# 4                                    174.676728
# 5                                    347.059430
# 6                                    346.187508
# 7                                    230.189248
# 8                                    592.437635
# 9                                      4.786260
# 10                                   496.159249
# 11                                   281.146946
# 12                                   310.085978
# 13                                   293.132914
# 14                                   279.286066
# 15                                   161.669946
# 16                                   174.153442
# 17                                    76.281835
# 18                                   124.422546
# 19                                   414.611772
# 20                                   285.796523
# 21                                   404.026998
# 22                                    46.629630
# 23                                   517.360795
# 24                                   163.770604
# 25                                   201.118704
# 26                                    26.042213
# 27                                   567.194418
# 28                                   363.951791
# 29                                   472.878750
# ..                                          ...
# 45                                   278.809751
# 46                                   107.051491
# 47                                   415.027469
# 48                                   231.242347
# 49                                   348.505279
# 50                                   175.730288
# 51                                   415.338491
# 52                                   106.998600
# 53                                   433.612499
# 54                                   580.639833
# 55                                   449.019574
# 56                                    57.567568
# 57                                   214.731998
# 58                                    51.332016
# 59                                   222.748005
# 60                                   151.628227
# 61                                   411.820052
# 62                                   433.746284
# 63                                   312.159288
# 64                                   277.160744
# 65                                   216.870634
# 66                                   210.500705
# 67                                   196.391327
# 68                                   480.035630
# 69                                    79.724445
# 70                                     3.182993
# 71                                   136.268260
# 72                                     6.259912
# 73                                   153.373214
# 74                                     3.587746
#
#     gradient_gldm_LargeDependenceHighGrayLevelEmphasis_flair  \
# 0                                          109.778032
# 1                                          332.035310
# 2                                          376.804183
# 3                                          719.936617
# 4                                          512.193677
# 5                                          600.375983
# 6                                          627.965469
# 7                                          553.715024
# 8                                          622.152675
# 9                                         2495.434421
# 10                                         595.877201
# 11                                         498.286984
# 12                                         519.722459
# 13                                         770.405847
# 14                                         567.038019
# 15                                         210.970036
# 16                                         723.397787
# 17                                         630.411856
# 18                                         696.251705
# 19                                         613.464085
# 20                                         521.012258
# 21                                         561.596469
# 22                                         145.970370
# 23                                         521.244460
# 24                                         621.366930
# 25                                         983.856975
# 26                                         128.812227
# 27                                         608.223467
# 28                                         573.659796
# 29                                         703.684622
# ..                                                ...
# 45                                         783.714997
# 46                                         853.226843
# 47                                         659.836351
# 48                                         525.093955
# 49                                         365.383442
# 50                                        1150.265847
# 51                                         561.325667
# 52                                         611.641560
# 53                                         615.722934
# 54                                         591.870404
# 55                                         523.065055
# 56                                         111.277027
# 57                                         375.298363
# 58                                          76.047431
# 59                                         624.111412
# 60                                         681.131970
# 61                                         551.153115
# 62                                         528.642585
# 63                                        1014.818515
# 64                                         959.976342
# 65                                         574.113561
# 66                                         689.276921
# 67                                         536.635809
# 68                                         547.610173
# 69                                         464.373693
# 70                                        9794.768562
# 71                                         554.894756
# 72                                        6432.372948
# 73                                         532.401450
# 74                                        6031.431707
#
#     gradient_gldm_LargeDependenceLowGrayLevelEmphasis_flair  \
# 0                                           91.394562
# 1                                            5.553936
# 2                                          280.813886
# 3                                          250.014407
# 4                                          120.849096
# 5                                          301.185661
# 6                                          291.428430
# 7                                          179.486462
# 8                                          585.612432
# 9                                            0.027403
# 10                                         477.637646
# 11                                         244.413105
# 12                                         265.172372
# 13                                         202.583559
# 14                                         228.893754
# 15                                         150.006541
# 16                                          94.746668
# 17                                          22.746927
# 18                                          56.043275
# 19                                         380.874701
# 20                                         246.116693
# 21                                         370.929281
# 22                                          29.873192
# 23                                         516.973680
# 24                                         109.947748
# 25                                         130.669674
# 26                                          10.773645
# 27                                         557.069527
# 28                                         317.278873
# 29                                         436.529113
# ..                                                ...
# 45                                         192.159690
# 46                                          34.395444
# 47                                         390.425935
# 48                                         183.934410
# 49                                         346.379333
# 50                                          92.956371
# 51                                         381.993878
# 52                                          31.166073
# 53                                         395.531637
# 54                                         577.855296
# 55                                         432.753228
# 56                                          45.754118
# 57                                         186.174752
# 58                                          45.339296
# 59                                         140.153927
# 60                                          59.430834
# 61                                         383.319882
# 62                                         419.566228
# 63                                         225.627192
# 64                                         203.674713
# 65                                         146.996804
# 66                                         132.611812
# 67                                         126.477453
# 68                                         468.945448
# 69                                          36.053602
# 70                                           0.007348
# 71                                          77.421896
# 72                                           0.036872
# 73                                          92.779329
# 74                                           0.010612
#
#     gradient_gldm_LowGrayLevelEmphasis_flair  \
# 0                                   0.855406
# 1                                   0.198197
# 2                                   0.834803
# 3                                   0.667348
# 4                                   0.472414
# 5                                   0.684681
# 6                                   0.645751
# 7                                   0.539736
# 8                                   0.940775
# 9                                   0.007745
# 10                                  0.857927
# 11                                  0.647804
# 12                                  0.695171
# 13                                  0.556620
# 14                                  0.604299
# 15                                  0.802785
# 16                                  0.398925
# 17                                  0.226454
# 18                                  0.313791
# 19                                  0.742460
# 20                                  0.652850
# 21                                  0.767030
# 22                                  0.393953
# 23                                  0.978919
# 24                                  0.409488
# 25                                  0.340725
# 26                                  0.420227
# 27                                  0.936802
# 28                                  0.717431
# 29                                  0.767238
# ..                                       ...
# 45                                  0.509912
# 46                                  0.234798
# 47                                  0.701596
# 48                                  0.554883
# 49                                  0.941623
# 50                                  0.328128
# 51                                  0.804080
# 52                                  0.280246
# 53                                  0.801707
# 54                                  0.973833
# 55                                  0.873081
# 56                                  0.649388
# 57                                  0.630461
# 58                                  0.804053
# 59                                  0.516514
# 60                                  0.362006
# 61                                  0.789366
# 62                                  0.789046
# 63                                  0.502121
# 64                                  0.486190
# 65                                  0.526620
# 66                                  0.466127
# 67                                  0.513639
# 68                                  0.901175
# 69                                  0.302168
# 70                                  0.001930
# 71                                  0.401939
# 72                                  0.004364
# 73                                  0.446296
# 74                                  0.002609
#
#     gradient_gldm_SmallDependenceEmphasis_flair  \
# 0                                      0.065322
# 1                                      0.134303
# 2                                      0.023494
# 3                                      0.010390
# 4                                      0.046263
# 5                                      0.020191
# 6                                      0.018428
# 7                                      0.036880
# 8                                      0.005255
# 9                                      0.570217
# 10                                     0.008979
# 11                                     0.028382
# 12                                     0.013864
# 13                                     0.016243
# 14                                     0.027467
# 15                                     0.026261
# 16                                     0.030041
# 17                                     0.072554
# 18                                     0.059886
# 19                                     0.015788
# 20                                     0.018121
# 21                                     0.012560
# 22                                     0.143321
# 23                                     0.008069
# 24                                     0.045955
# 25                                     0.053378
# 26                                     0.172598
# 27                                     0.005350
# 28                                     0.012111
# 29                                     0.014180
# ..                                          ...
# 45                                     0.021907
# 46                                     0.075200
# 47                                     0.020741
# 48                                     0.032628
# 49                                     0.018395
# 50                                     0.042952
# 51                                     0.009640
# 52                                     0.056985
# 53                                     0.007384
# 54                                     0.003400
# 55                                     0.011432
# 56                                     0.181545
# 57                                     0.043431
# 58                                     0.100837
# 59                                     0.020493
# 60                                     0.041087
# 61                                     0.013714
# 62                                     0.026089
# 63                                     0.015902
# 64                                     0.027165
# 65                                     0.025246
# 66                                     0.036966
# 67                                     0.038472
# 68                                     0.011114
# 69                                     0.086955
# 70                                     0.685475
# 71                                     0.057645
# 72                                     0.509004
# 73                                     0.054329
# 74                                     0.639416
#
#     gradient_gldm_SmallDependenceHighGrayLevelEmphasis_flair  \
# 0                                            0.216538
# 1                                            3.715464
# 2                                            0.106719
# 3                                            0.049565
# 4                                            1.512628
# 5                                            0.635871
# 6                                            0.391621
# 7                                            0.755513
# 8                                            0.022291
# 9                                          566.267711
# 10                                           0.085528
# 11                                           0.816873
# 12                                           0.242938
# 13                                           0.264215
# 14                                           0.847956
# 15                                           0.124227
# 16                                           0.669037
# 17                                           2.917307
# 18                                           3.836028
# 19                                           0.294170
# 20                                           0.177039
# 21                                           0.205195
# 22                                           2.568945
# 23                                           0.052630
# 24                                           1.309576
# 25                                           5.310077
# 26                                           1.416320
# 27                                           0.016890
# 28                                           0.098297
# 29                                           0.234234
# ..                                                ...
# 45                                           0.416837
# 46                                          11.776832
# 47                                           0.359719
# 48                                           0.702959
# 49                                           0.208080
# 50                                           8.431685
# 51                                           0.043209
# 52                                           2.378870
# 53                                           0.038919
# 54                                           0.007628
# 55                                           0.059332
# 56                                           1.179759
# 57                                           0.567155
# 58                                           0.257863
# 59                                           0.283279
# 60                                           1.357366
# 61                                           0.102883
# 62                                           0.947217
# 63                                           0.291871
# 64                                           1.389256
# 65                                           0.431292
# 66                                           2.604278
# 67                                           2.068665
# 68                                           0.141825
# 69                                           3.466448
# 70                                        4008.872372
# 71                                           4.976351
# 72                                        1668.574651
# 73                                           4.276194
# 74                                        2190.396608
#
#     gradient_gldm_SmallDependenceLowGrayLevelEmphasis_flair   age  surv  \
# 0                                            0.039544        None  None
# 1                                            0.028742        None  None
# 2                                            0.012819        None  None
# 3                                            0.005074        None  None
# 4                                            0.007328        None  None
# 5                                            0.004703        None  None
# 6                                            0.004453        None  None
# 7                                            0.009531        None  None
# 8                                            0.002631        None  None
# 9                                            0.005240        None  None
# 10                                           0.003234        None  None
# 11                                           0.006966        None  None
# 12                                           0.004659        None  None
# 13                                           0.004501        None  None
# 14                                           0.005449        None  None
# 15                                           0.011562        None  None
# 16                                           0.007257        None  None
# 17                                           0.013691        None  None
# 18                                           0.010503        None  None
# 19                                           0.003721        None  None
# 20                                           0.005906        None  None
# 21                                           0.004256        None  None
# 22                                           0.029790        None  None
# 23                                           0.004600        None  None
# 24                                           0.007640        None  None
# 25                                           0.006731        None  None
# 26                                           0.069108        None  None
# 27                                           0.003143        None  None
# 28                                           0.004121        None  None
# 29                                           0.003755        None  None
# ..                                                ...         ...   ...
# 45                                           0.005488        None  None
# 46                                           0.012497        None  None
# 47                                           0.004906        None  None
# 48                                           0.007578        None  None
# 49                                           0.008499        None  None
# 50                                           0.005793        None  None
# 51                                           0.004349        None  None
# 52                                           0.012956        None  None
# 53                                           0.003350        None  None
# 54                                           0.002397        None  None
# 55                                           0.005052        None  None
# 56                                           0.091720        None  None
# 57                                           0.012696        None  None
# 58                                           0.070215        None  None
# 59                                           0.006381        None  None
# 60                                           0.009449        None  None
# 61                                           0.005458        None  None
# 62                                           0.004902        None  None
# 63                                           0.004043        None  None
# 64                                           0.005052        None  None
# 65                                           0.007047        None  None
# 66                                           0.005916        None  None
# 67                                           0.007965        None  None
# 68                                           0.004465        None  None
# 69                                           0.016467        None  None
# 70                                           0.001256        None  None
# 71                                           0.008604        None  None
# 72                                           0.001886        None  None
# 73                                           0.007955        None  None
# 74                                           0.001616        None  None
#
#                   sample
# 0   Brats18_TCIA13_653_1
# 1   Brats18_TCIA09_312_1
# 2   Brats18_TCIA10_449_1
# 3      Brats18_2013_16_1
# 4   Brats18_TCIA10_266_1
# 5   Brats18_TCIA12_466_1
# 6   Brats18_TCIA13_630_1
# 7       Brats18_2013_0_1
# 8      Brats18_2013_24_1
# 9   Brats18_TCIA09_620_1
# 10     Brats18_2013_28_1
# 11  Brats18_TCIA10_282_1
# 12  Brats18_TCIA09_254_1
# 13  Brats18_TCIA12_298_1
# 14  Brats18_TCIA13_634_1
# 15  Brats18_TCIA10_103_1
# 16  Brats18_TCIA10_625_1
# 17  Brats18_TCIA10_325_1
# 18  Brats18_TCIA10_346_1
# 19      Brats18_2013_8_1
# 20     Brats18_2013_15_1
# 21  Brats18_TCIA09_255_1
# 22  Brats18_TCIA09_428_1
# 23  Brats18_TCIA10_640_1
# 24  Brats18_TCIA13_650_1
# 25  Brats18_TCIA09_402_1
# 26  Brats18_TCIA10_629_1
# 27      Brats18_2013_9_1
# 28  Brats18_TCIA12_249_1
# 29  Brats18_TCIA12_480_1
# ..                   ...
# 45  Brats18_TCIA13_645_1
# 46  Brats18_TCIA09_141_1
# 47  Brats18_TCIA10_490_1
# 48  Brats18_TCIA10_442_1
# 49  Brats18_TCIA10_152_1
# 50  Brats18_TCIA10_393_1
# 51  Brats18_TCIA10_175_1
# 52  Brats18_TCIA10_330_1
# 53  Brats18_TCIA10_109_1
# 54      Brats18_2013_1_1
# 55  Brats18_TCIA13_621_1
# 56  Brats18_TCIA10_299_1
# 57  Brats18_TCIA10_408_1
# 58  Brats18_TCIA13_624_1
# 59  Brats18_TCIA09_462_1
# 60  Brats18_TCIA10_202_1
# 61  Brats18_TCIA10_644_1
# 62  Brats18_TCIA10_310_1
# 63  Brats18_TCIA13_615_1
# 64  Brats18_TCIA13_654_1
# 65  Brats18_TCIA10_130_1
# 66  Brats18_TCIA10_628_1
# 67  Brats18_TCIA10_351_1
# 68      Brats18_2013_6_1
# 69  Brats18_TCIA10_410_1
# 70  Brats18_TCIA10_632_1
# 71  Brats18_TCIA10_261_1
# 72  Brats18_TCIA10_639_1
# 73  Brats18_TCIA10_387_1
# 74  Brats18_TCIA10_637_1
#
# [75 rows x 5559 columns]

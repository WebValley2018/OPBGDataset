# %%
import os
import pydicom as pd
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %%
def read_dicoms(main_dir):
    dicoms_data = {}
    
    for directory in filter(lambda it: not it.startswith(".") and it != "VERSION", 
                            os.listdir(main_dir)):
        path = os.path.join(main_dir, directory)
        
        files = list(filter(lambda it: not it.startswith(".") and it != "VERSION", 
                           os.listdir(path)))
        
        if len(files) > 0:
            dicoms_data[os.path.join(path, files[0])] = pd.dcmread(os.path.join(path, files[0]))
    
    return dicoms_data

dicoms_data = read_dicoms("/Volumes/ACCMED/ioanpaul_OPBG0032/NOTC4GYK")

for path, file  in dicoms_data.items():
    print(file)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20150905'
# (0008, 0013) Instance Creation Time              TM: '145040.018000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.19.45131.2015090514503829235421511
# (0008, 0020) Study Date                          DA: '20150905'
# (0008, 0021) Series Date                         DA: '20150905'
# (0008, 0022) Acquisition Date                    DA: '20150905'
# (0008, 0023) Content Date                        DA: '20150905'
# (0008, 0030) Study Time                          TM: '141404.022000'
# (0008, 0031) Series Time                         TM: '145039.961000'
# (0008, 0032) Acquisition Time                    TM: '145033.435000'
# (0008, 0033) Content Time                        TM: '145040.018000'
# (0008, 0050) Accession Number                    SH: 'P103071356'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0061) Modalities in Study                 CS: ['MR', 'SR']
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Ospedale Bambin Gesu'
# (0008, 0081) Institution Address                 ST: 'Pizza S. Onofrio 4,Roma,District,IT,00165'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP45131'
# (0008, 1030) Study Description                   LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0008, 103e) Series Description                  LO: 'diffusione 0 1000_ADC'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514315348615018602
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514331020737018751
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514331620405818771
#    ---------
# (0010, 0010) Patient's Name                      PN: 'MARINO^MARISSA'
# (0010, 0020) Patient ID                          LO: 'P16067041'
# (0010, 0021) Issuer of Patient ID                LO: 'opbgpacs'
# (0010, 0030) Patient's Birth Date                DA: '20131127'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1002)  Other Patient IDs Sequence   1 item(s) ----
#
#    ---------
# (0010, 1010) Patient's Age                       AS: '021M'
# (0010, 1020) Patient's Size                      DS: "0.8"
# (0010, 1030) Patient's Weight                    DS: "9"
# (0018, 0015) Body Part Examined                  CS: 'HEAD'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: '*ep_b0_1000'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "3"
# (0018, 0080) Repetition Time                     DS: "9000"
# (0018, 0081) Echo Time                           DS: "98"
# (0018, 0083) Number of Averages                  DS: "3"
# (0018, 0084) Imaging Frequency                   DS: "123.258845"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "3.6"
# (0018, 0089) Number of Phase Encoding Steps      IS: '143'
# (0018, 0091) Echo Train Length                   IS: '71'
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "100"
# (0018, 0095) Pixel Bandwidth                     DS: "1040"
# (0018, 1000) Device Serial Number                LO: '45131'
# (0018, 1020) Software Version(s)                 LO: 'syngo MR D13'
# (0018, 1030) Protocol Name                       LO: 'diffusione 0 1000'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [192, 0, 0, 192]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "90"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.45171819076174"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 100c) [B_value]                           IS: '1000'
# (0019, 100d) [DiffusionDirectionality]           CS: 'ISOTROPIC'
# (0020, 000d) Study Instance UID                  UI: 1.3.76.8.100.240425.905314
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.19.45131.2015090514483912945719760.0.0.0
# (0020, 0010) Study ID                            SH: 'REQ2015005370983'
# (0020, 0011) Series Number                       IS: '10'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['-107.49291936662', '-87.64815838848', '-53.708314698158']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.99965454161401', '-0.0190766919247', '-0.0180797471136', '0.02093981973803', '0.99380006942525', '0.10919224312977']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45131.1.20150905142748219.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-45.485452090677"
# (0020, 1208) Number of Study Related Instances   IS: '2957'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 192
# (0028, 0011) Columns                             US: 192
# (0028, 0030) Pixel Spacing                       DS: ['1.1458333730698', '1.1458333730698']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3277
# (0028, 1050) Window Center                       DS: "690"
# (0028, 1051) Window Width                        DS: "1741"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0032, 1060) Requested Procedure Description     LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0244) Performed Procedure Step Start Date DA: '20150905'
# (0040, 0245) Performed Procedure Step Start Time TM: '141404.144000'
# (0040, 0253) Performed Procedure Step ID         SH: '572'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
#    (0040, 0009) Scheduled Procedure Step ID         SH: '572'
#    (0040, 1001) Requested Procedure ID              SH: 'REQ2015005370983'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0040, 1008) Confidentiality Code                ST: 'N'
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0088, 0200)  Icon Image Sequence   1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0034) Pixel Aspect Ratio                  IS: ['1', '1']
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (7fe0, 0010) Pixel Data                          OB: Array of 4096 bytes
#    ---------
# (07a1, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a1, 1002) [number of images in series]        UL: 40
# (07a1, 102a) [Tamar Study Status]                CS: 'READ'
# (07a1, 1040) [Tamar Study Body Part]             CS: 'HEAD'
# (07a1, 1042) Private tag data                    SH: 'NOT ASSIGNED'
# (07a1, 1043) [Unknown]                           IS: '1'
# (07a1, 1050) [Tamar Site Id]                     US: 604
# (07a1, 1058) Private tag data                    CS: 'A'
# (07a1, 105f) Private tag data                    CS: 'N'
# (07a1, 1070) Private tag data                    SH: 'GIA'
# (07a1, 1071) Private tag data                    SH: '1'
# (07a1, 1085) [Tamar Translate Flags]             UL: 3
# (07a1, 10c2) Private tag data                    ST: 'MIG LOC SOURCE 10 TBD'
# (07a1, 10d0) Private tag data                    LO: '4157885775873'
# (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a3, 1001) [Tamar Exe Software Version]        LO: '12.1.5.0'
# (07a3, 1003) [Tamar Study Has Sticky Note]       CS: 'N'
# (07a3, 1013) Private tag data                    SH: 'I'
# (07a3, 1014) Private tag data                    ST: '572'
# (07a3, 1015) Private tag data                    ST: '000004571010'
# (07a3, 1017) Private tag data                    SH: 'SC'
# (07a3, 101b) Private tag data                    ST: 'DL'
# (07a3, 101c) Private tag data                    ST: 'LONGO'
# (07a3, 101d) Private tag data                    ST: 'DANIELA'
# (07a3, 101e) Private tag data                    ST: 'DL'
# (07a3, 1024) Private tag data                    ST: 'RM NEUROCHIRURGIA RO'
# (07a3, 1034) [Tamar Study Age]                   SH: '652'
# (07a3, 1055) [Unknown]                           SH: 'N'
# (07a3, 105c) Private tag data                    ST: '0'
# (07a3, 108f) Private tag data                    CS: 'N'
# (07a3, 1099) [Unknown]                           CS: 'N'
# (07a3, 109c) [Unknown]                           CS: 'N'
# (07a3, 10b9) Private tag data                    CS: 'N'
# (07a3, 10bb) Private tag data                    CS: 'N'
# (07a3, 10c0)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10ca)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10cb)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a5, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a5, 1054) Private tag data                    DT: '20150905153900.000000'
# (07a5, 1056) Private tag data                    CS: 'N'
# (07a5, 1059) Private tag data                    IS: '8'
# (07a5, 10c8) Private tag data                    CS: 'Y'
# (7fe0, 0010) Pixel Data                          OW: Array of 73728 bytes
# SEPARATOR
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20150905'
# (0008, 0013) Instance Creation Time              TM: '145039.813000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.19.45131.2015090514503827642321505
# (0008, 0020) Study Date                          DA: '20150905'
# (0008, 0021) Series Date                         DA: '20150905'
# (0008, 0022) Acquisition Date                    DA: '20150905'
# (0008, 0023) Content Date                        DA: '20150905'
# (0008, 0030) Study Time                          TM: '141404.022000'
# (0008, 0031) Series Time                         TM: '145039.695000'
# (0008, 0032) Acquisition Time                    TM: '144912.435000'
# (0008, 0033) Content Time                        TM: '145039.813000'
# (0008, 0050) Accession Number                    SH: 'P103071356'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0061) Modalities in Study                 CS: ['MR', 'SR']
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Ospedale Bambin Gesu'
# (0008, 0081) Institution Address                 ST: 'Pizza S. Onofrio 4,Roma,District,IT,00165'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP45131'
# (0008, 1030) Study Description                   LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0008, 103e) Series Description                  LO: 'diffusione 0 1000_TRACEW'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514315348615018602
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514331020737018751
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514331620405818771
#    ---------
# (0010, 0010) Patient's Name                      PN: 'MARINO^MARISSA'
# (0010, 0020) Patient ID                          LO: 'P16067041'
# (0010, 0021) Issuer of Patient ID                LO: 'opbgpacs'
# (0010, 0030) Patient's Birth Date                DA: '20131127'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1002)  Other Patient IDs Sequence   1 item(s) ----
#
#    ---------
# (0010, 1010) Patient's Age                       AS: '021M'
# (0010, 1020) Patient's Size                      DS: "0.8"
# (0010, 1030) Patient's Weight                    DS: "9"
# (0018, 0015) Body Part Examined                  CS: 'HEAD'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: '*ep_b0'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "3"
# (0018, 0080) Repetition Time                     DS: "9000"
# (0018, 0081) Echo Time                           DS: "98"
# (0018, 0083) Number of Averages                  DS: "1"
# (0018, 0084) Imaging Frequency                   DS: "123.258845"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "3.6"
# (0018, 0089) Number of Phase Encoding Steps      IS: '143'
# (0018, 0091) Echo Train Length                   IS: '71'
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "100"
# (0018, 0095) Pixel Bandwidth                     DS: "1040"
# (0018, 1000) Device Serial Number                LO: '45131'
# (0018, 1020) Software Version(s)                 LO: 'syngo MR D13'
# (0018, 1030) Protocol Name                       LO: 'diffusione 0 1000'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [192, 0, 0, 192]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "90"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.45171819076174"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 100c) [B_value]                           IS: '0'
# (0019, 100d) [DiffusionDirectionality]           CS: 'ISOTROPIC'
# (0020, 000d) Study Instance UID                  UI: 1.3.76.8.100.240425.905314
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.19.45131.2015090514483912945619759.0.0.0
# (0020, 0010) Study ID                            SH: 'REQ2015005370983'
# (0020, 0011) Series Number                       IS: '9'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['-107.49291936662', '-87.64815838848', '-53.708314698158']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.99965454161401', '-0.0190766919247', '-0.0180797471136', '0.02093981973803', '0.99380006942525', '0.10919224312977']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45131.1.20150905142748219.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-45.485452090677"
# (0020, 1208) Number of Study Related Instances   IS: '2957'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 192
# (0028, 0011) Columns                             US: 192
# (0028, 0030) Pixel Spacing                       DS: ['1.1458333730698', '1.1458333730698']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2149
# (0028, 1050) Window Center                       DS: "392"
# (0028, 1051) Window Width                        DS: "822"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0032, 1060) Requested Procedure Description     LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0244) Performed Procedure Step Start Date DA: '20150905'
# (0040, 0245) Performed Procedure Step Start Time TM: '141404.144000'
# (0040, 0253) Performed Procedure Step ID         SH: '572'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
#    (0040, 0009) Scheduled Procedure Step ID         SH: '572'
#    (0040, 1001) Requested Procedure ID              SH: 'REQ2015005370983'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0040, 1008) Confidentiality Code                ST: 'N'
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0088, 0200)  Icon Image Sequence   1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0034) Pixel Aspect Ratio                  IS: ['1', '1']
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (7fe0, 0010) Pixel Data                          OB: Array of 4096 bytes
#    ---------
# (07a1, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a1, 1002) [number of images in series]        UL: 80
# (07a1, 102a) [Tamar Study Status]                CS: 'READ'
# (07a1, 1040) [Tamar Study Body Part]             CS: 'HEAD'
# (07a1, 1042) Private tag data                    SH: 'NOT ASSIGNED'
# (07a1, 1043) [Unknown]                           IS: '1'
# (07a1, 1050) [Tamar Site Id]                     US: 604
# (07a1, 1058) Private tag data                    CS: 'A'
# (07a1, 105f) Private tag data                    CS: 'N'
# (07a1, 1070) Private tag data                    SH: 'GIA'
# (07a1, 1071) Private tag data                    SH: '1'
# (07a1, 1085) [Tamar Translate Flags]             UL: 3
# (07a1, 10c2) Private tag data                    ST: 'MIG LOC SOURCE 10 TBD'
# (07a1, 10d0) Private tag data                    LO: '4157880467457'
# (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a3, 1001) [Tamar Exe Software Version]        LO: '12.1.5.0'
# (07a3, 1003) [Tamar Study Has Sticky Note]       CS: 'N'
# (07a3, 1013) Private tag data                    SH: 'I'
# (07a3, 1014) Private tag data                    ST: '572'
# (07a3, 1015) Private tag data                    ST: '000004571010'
# (07a3, 1017) Private tag data                    SH: 'SC'
# (07a3, 101b) Private tag data                    ST: 'DL'
# (07a3, 101c) Private tag data                    ST: 'LONGO'
# (07a3, 101d) Private tag data                    ST: 'DANIELA'
# (07a3, 101e) Private tag data                    ST: 'DL'
# (07a3, 1024) Private tag data                    ST: 'RM NEUROCHIRURGIA RO'
# (07a3, 1034) [Tamar Study Age]                   SH: '652'
# (07a3, 1055) [Unknown]                           SH: 'N'
# (07a3, 105c) Private tag data                    ST: '0'
# (07a3, 108f) Private tag data                    CS: 'N'
# (07a3, 1099) [Unknown]                           CS: 'N'
# (07a3, 109c) [Unknown]                           CS: 'N'
# (07a3, 10b9) Private tag data                    CS: 'N'
# (07a3, 10bb) Private tag data                    CS: 'N'
# (07a3, 10c0)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10ca)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10cb)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a5, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a5, 1054) Private tag data                    DT: '20150905153900.000000'
# (07a5, 1056) Private tag data                    CS: 'N'
# (07a5, 1059) Private tag data                    IS: '7'
# (07a5, 10c8) Private tag data                    CS: 'Y'
# (7fe0, 0010) Pixel Data                          OW: Array of 73728 bytes
# SEPARATOR
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# (0008, 0012) Instance Creation Date              DA: '20150905'
# (0008, 0013) Instance Creation Time              TM: '152034.681000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.19.45131.2015090515203414844325985
# (0008, 0020) Study Date                          DA: '20150905'
# (0008, 0021) Series Date                         DA: '20150905'
# (0008, 0022) Acquisition Date                    DA: '20150905'
# (0008, 0023) Content Date                        DA: '20150905'
# (0008, 0030) Study Time                          TM: '141404.022000'
# (0008, 0031) Series Time                         TM: '152034.677000'
# (0008, 0032) Acquisition Time                    TM: '151816.835000'
# (0008, 0033) Content Time                        TM: '152034.681000'
# (0008, 0050) Accession Number                    SH: 'P103071356'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0061) Modalities in Study                 CS: ['MR', 'SR']
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Ospedale Bambin Gesu'
# (0008, 0081) Institution Address                 ST: 'Pizza S. Onofrio 4,Roma,District,IT,00165'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP45131'
# (0008, 1030) Study Description                   LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0008, 103e) Series Description                  LO: 't2_tse_sag_384'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515150491199325353
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.201509051514279278724778
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515145828926025344
#    ---------
# (0010, 0010) Patient's Name                      PN: 'MARINO^MARISSA'
# (0010, 0020) Patient ID                          LO: 'P16067041'
# (0010, 0021) Issuer of Patient ID                LO: 'opbgpacs'
# (0010, 0030) Patient's Birth Date                DA: '20131127'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1002)  Other Patient IDs Sequence   1 item(s) ----
#
#    ---------
# (0010, 1010) Patient's Age                       AS: '021M'
# (0010, 1020) Patient's Size                      DS: "0.8"
# (0010, 1030) Patient's Weight                    DS: "9"
# (0018, 0015) Body Part Examined                  CS: 'HEAD'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: 'SAT1'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: '*tseR2d1rr22'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "3"
# (0018, 0080) Repetition Time                     DS: "3500"
# (0018, 0081) Echo Time                           DS: "114"
# (0018, 0083) Number of Averages                  DS: "3"
# (0018, 0084) Imaging Frequency                   DS: "123.258788"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "3.3"
# (0018, 0089) Number of Phase Encoding Steps      IS: '572'
# (0018, 0091) Echo Train Length                   IS: '22'
# (0018, 0093) Percent Sampling                    DS: "70"
# (0018, 0094) Percent Phase Field of View         DS: "100"
# (0018, 0095) Pixel Bandwidth                     DS: "260"
# (0018, 1000) Device Serial Number                LO: '45131'
# (0018, 1020) Software Version(s)                 LO: 'syngo MR D13'
# (0018, 1030) Protocol Name                       LO: 't2_tse_sag_384'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [384, 0, 0, 269]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "160"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "3.3632588739164"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0020, 000d) Study Instance UID                  UI: 1.3.76.8.100.240425.905314
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.19.45131.2015090515203427735426002.0.0.0
# (0020, 0010) Study ID                            SH: 'REQ2015005370983'
# (0020, 0011) Series Number                       IS: '25'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['-1.4285412466221', '-74.509407804251', '-170.54829617023']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.00607903526923', '0.99998152249439', '-3.38882e-010', '0.0155062407752', '-9.42650652e-005', '-0.9998797665775']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45131.2.20150905142748219.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-3.6200640475357"
# (0020, 1208) Number of Study Related Instances   IS: '2957'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 384
# (0028, 0011) Columns                             US: 384
# (0028, 0030) Pixel Spacing                       DS: ['0.59895831346512', '0.59895831346512']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 856
# (0028, 1050) Window Center                       DS: "379"
# (0028, 1051) Window Width                        DS: "830"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0032, 1060) Requested Procedure Description     LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0244) Performed Procedure Step Start Date DA: '20150905'
# (0040, 0245) Performed Procedure Step Start Time TM: '141404.144000'
# (0040, 0253) Performed Procedure Step ID         SH: '572'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
#    (0040, 0009) Scheduled Procedure Step ID         SH: '572'
#    (0040, 1001) Requested Procedure ID              SH: 'REQ2015005370983'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0040, 1008) Confidentiality Code                ST: 'N'
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0088, 0200)  Icon Image Sequence   1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0034) Pixel Aspect Ratio                  IS: ['1', '1']
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (7fe0, 0010) Pixel Data                          OB: Array of 4096 bytes
#    ---------
# (07a1, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a1, 1002) [number of images in series]        UL: 13
# (07a1, 102a) [Tamar Study Status]                CS: 'READ'
# (07a1, 1040) [Tamar Study Body Part]             CS: 'HEAD'
# (07a1, 1042) Private tag data                    SH: 'NOT ASSIGNED'
# (07a1, 1043) [Unknown]                           IS: '1'
# (07a1, 1050) [Tamar Site Id]                     US: 604
# (07a1, 1058) Private tag data                    CS: 'A'
# (07a1, 105f) Private tag data                    CS: 'N'
# (07a1, 1070) Private tag data                    SH: 'GIA'
# (07a1, 1071) Private tag data                    SH: '1'
# (07a1, 1085) [Tamar Translate Flags]             UL: 3
# (07a1, 10c2) Private tag data                    ST: 'MIG LOC SOURCE 10 TBD'
# (07a1, 10d0) Private tag data                    LO: '4157957996545'
# (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a3, 1001) [Tamar Exe Software Version]        LO: '12.1.5.0'
# (07a3, 1003) [Tamar Study Has Sticky Note]       CS: 'N'
# (07a3, 1013) Private tag data                    SH: 'I'
# (07a3, 1014) Private tag data                    ST: '572'
# (07a3, 1015) Private tag data                    ST: '000004571010'
# (07a3, 1017) Private tag data                    SH: 'SC'
# (07a3, 101b) Private tag data                    ST: 'DL'
# (07a3, 101c) Private tag data                    ST: 'LONGO'
# (07a3, 101d) Private tag data                    ST: 'DANIELA'
# (07a3, 101e) Private tag data                    ST: 'DL'
# (07a3, 1024) Private tag data                    ST: 'RM NEUROCHIRURGIA RO'
# (07a3, 1034) [Tamar Study Age]                   SH: '652'
# (07a3, 1055) [Unknown]                           SH: 'N'
# (07a3, 105c) Private tag data                    ST: '0'
# (07a3, 108f) Private tag data                    CS: 'N'
# (07a3, 1099) [Unknown]                           CS: 'N'
# (07a3, 109c) [Unknown]                           CS: 'N'
# (07a3, 10b9) Private tag data                    CS: 'N'
# (07a3, 10bb) Private tag data                    CS: 'N'
# (07a3, 10c0)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10ca)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10cb)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a5, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a5, 1054) Private tag data                    DT: '20150905153900.000000'
# (07a5, 1056) Private tag data                    CS: 'N'
# (07a5, 1059) Private tag data                    IS: '23'
# (07a5, 10c8) Private tag data                    CS: 'Y'
# (7fe0, 0010) Pixel Data                          OW: Array of 294912 bytes
# SEPARATOR
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', 'ND', 'NORM', 'MOSAIC']
# (0008, 0012) Instance Creation Date              DA: '20150905'
# (0008, 0013) Instance Creation Time              TM: '152605.077000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.19.45131.2015090515233185228327480
# (0008, 0020) Study Date                          DA: '20150905'
# (0008, 0021) Series Date                         DA: '20150905'
# (0008, 0022) Acquisition Date                    DA: '20150905'
# (0008, 0023) Content Date                        DA: '20150905'
# (0008, 0030) Study Time                          TM: '141404.022000'
# (0008, 0031) Series Time                         TM: '152605.072000'
# (0008, 0032) Acquisition Time                    TM: '152323.300000'
# (0008, 0033) Content Time                        TM: '152605.077000'
# (0008, 0050) Accession Number                    SH: 'P103071356'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0061) Modalities in Study                 CS: ['MR', 'SR']
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Ospedale Bambin Gesu'
# (0008, 0081) Institution Address                 ST: 'Pizza S. Onofrio 4,Roma,District,IT,00165'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP45131'
# (0008, 1030) Study Description                   LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0008, 103e) Series Description                  LO: 'DTI_ANTONIO_30_1_AVERAGE 2X2X2mm'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514332820289518811
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090514315348615018602
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.201509051514279278724778
#    ---------
# (0008, 2112)  Source Image Sequence   45 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232430045827214
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232444945927221
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232463559727227
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232472911827233
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232484080827239
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232515451827245
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232532634927251
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232550103027257
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232567655627263
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232584964227269
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.201509051523262508327275
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232613080027281
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232624754627287
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232656491127293
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232673013827299
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232690648627305
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.201509051523277950827311
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232725296627317
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232742728727323
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232753290127329
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232764333227335
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232796065527341
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232813995727347
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232831576327353
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232849069427359
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232865384427365
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232882347027371
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515232893183627377
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.201509051523294640327383
#    ---------
# ...
# (07a3, 1034) [Tamar Study Age]                   SH: '652'
# (07a3, 1055) [Unknown]                           SH: 'N'
# (07a3, 105c) Private tag data                    ST: '0'
# (07a3, 108f) Private tag data                    CS: 'N'
# (07a3, 1099) [Unknown]                           CS: 'N'
# (07a3, 109c) [Unknown]                           CS: 'N'
# (07a3, 10b9) Private tag data                    CS: 'N'
# (07a3, 10bb) Private tag data                    CS: 'N'
# (07a3, 10c0)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10ca)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10cb)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a5, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a5, 1054) Private tag data                    DT: '20150905153900.000000'
# (07a5, 1056) Private tag data                    CS: 'N'
# (07a5, 1059) Private tag data                    IS: '0'
# (07a5, 10c8) Private tag data                    CS: 'Y'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# SEPARATOR
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# (0008, 0012) Instance Creation Date              DA: '20150905'
# (0008, 0013) Instance Creation Time              TM: '151500.212000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.19.45131.2015090515145828926025344
# (0008, 0020) Study Date                          DA: '20150905'
# (0008, 0021) Series Date                         DA: '20150905'
# (0008, 0022) Acquisition Date                    DA: '20150905'
# (0008, 0023) Content Date                        DA: '20150905'
# (0008, 0030) Study Time                          TM: '141404.022000'
# (0008, 0031) Series Time                         TM: '151449.583000'
# (0008, 0032) Acquisition Time                    TM: '151455.407500'
# (0008, 0033) Content Time                        TM: '151500.212000'
# (0008, 0050) Accession Number                    SH: 'P103071356'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0061) Modalities in Study                 CS: ['MR', 'SR']
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Ospedale Bambin Gesu'
# (0008, 0081) Institution Address                 ST: 'Pizza S. Onofrio 4,Roma,District,IT,00165'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP45131'
# (0008, 1030) Study Description                   LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0008, 103e) Series Description                  LO: 'localizer'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515073859532624108
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515073417959424102
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.19.45131.2015090515050321841124042
#    ---------
# (0010, 0010) Patient's Name                      PN: 'MARINO^MARISSA'
# (0010, 0020) Patient ID                          LO: 'P16067041'
# (0010, 0021) Issuer of Patient ID                LO: 'opbgpacs'
# (0010, 0030) Patient's Birth Date                DA: '20131127'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1002)  Other Patient IDs Sequence   1 item(s) ----
#
#    ---------
# (0010, 1010) Patient's Age                       AS: '021M'
# (0010, 1020) Patient's Size                      DS: "0.8"
# (0010, 1030) Patient's Weight                    DS: "9"
# (0018, 0015) Body Part Examined                  CS: 'HEAD'
# (0018, 0020) Scanning Sequence                   CS: 'GR'
# (0018, 0021) Sequence Variant                    CS: ['SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ''
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: '*fl2d1'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "6"
# (0018, 0080) Repetition Time                     DS: "7.8"
# (0018, 0081) Echo Time                           DS: "3.69"
# (0018, 0083) Number of Averages                  DS: "1"
# (0018, 0084) Imaging Frequency                   DS: "123.258836"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "9"
# (0018, 0089) Number of Phase Encoding Steps      IS: '283'
# (0018, 0091) Echo Train Length                   IS: '1'
# (0018, 0093) Percent Sampling                    DS: "80"
# (0018, 0094) Percent Phase Field of View         DS: "100"
# (0018, 0095) Pixel Bandwidth                     DS: "320"
# (0018, 1000) Device Serial Number                LO: '45131'
# (0018, 1020) Software Version(s)                 LO: 'syngo MR D13'
# (0018, 1030) Protocol Name                       LO: 'localizer'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 205, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "20"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.12083097758937"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0020, 000d) Study Instance UID                  UI: 1.3.76.8.100.240425.905314
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.19.45131.2015090515144521774425327.0.0.0
# (0020, 0010) Study ID                            SH: 'REQ2015005370983'
# (0020, 0011) Series Number                       IS: '23'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['16.584914638754', '-115.11244766562', '-209.15643515882']
# (0020, 0037) Image Orientation (Patient)         DS: ['-0.0040759792456', '0.99999169316209', '2.5317884e-008', '0.0247135905513', '0.0001007582293', '-0.9996945675004']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45131.2.20150905142748219.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "10.941609313152"
# (0020, 1208) Number of Study Related Instances   IS: '2957'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 490
# (0028, 1050) Window Center                       DS: "128"
# (0028, 1051) Window Width                        DS: "349"
# (0028, 1055) Window Center & Width Explanation   LO: 'WINDOW1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0032, 1060) Requested Procedure Description     LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0244) Performed Procedure Step Start Date DA: '20150905'
# (0040, 0245) Performed Procedure Step Start Time TM: '141404.144000'
# (0040, 0253) Performed Procedure Step ID         SH: '572'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'RM ENCEFALO (SENZA E CON CONTRASTO)'
#    (0040, 0009) Scheduled Procedure Step ID         SH: '572'
#    (0040, 1001) Requested Procedure ID              SH: 'REQ2015005370983'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0040, 1008) Confidentiality Code                ST: 'N'
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0088, 0200)  Icon Image Sequence   1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0034) Pixel Aspect Ratio                  IS: ['1', '1']
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (7fe0, 0010) Pixel Data                          OB: Array of 4096 bytes
#    ---------
# (07a1, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a1, 1002) [number of images in series]        UL: 8
# (07a1, 102a) [Tamar Study Status]                CS: 'READ'
# (07a1, 1040) [Tamar Study Body Part]             CS: 'HEAD'
# (07a1, 1042) Private tag data                    SH: 'NOT ASSIGNED'
# (07a1, 1043) [Unknown]                           IS: '1'
# (07a1, 1050) [Tamar Site Id]                     US: 604
# (07a1, 1058) Private tag data                    CS: 'A'
# (07a1, 105f) Private tag data                    CS: 'N'
# (07a1, 1070) Private tag data                    SH: 'GIA'
# (07a1, 1071) Private tag data                    SH: '1'
# (07a1, 1085) [Tamar Translate Flags]             UL: 3
# (07a1, 10c2) Private tag data                    ST: 'MIG LOC SOURCE 10 TBD'
# (07a1, 10d0) Private tag data                    LO: '4157956489217'
# (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a3, 1001) [Tamar Exe Software Version]        LO: '12.1.5.0'
# (07a3, 1003) [Tamar Study Has Sticky Note]       CS: 'N'
# (07a3, 1013) Private tag data                    SH: 'I'
# (07a3, 1014) Private tag data                    ST: '572'
# (07a3, 1015) Private tag data                    ST: '000004571010'
# (07a3, 1017) Private tag data                    SH: 'SC'
# (07a3, 101b) Private tag data                    ST: 'DL'
# (07a3, 101c) Private tag data                    ST: 'LONGO'
# (07a3, 101d) Private tag data                    ST: 'DANIELA'
# (07a3, 101e) Private tag data                    ST: 'DL'
# (07a3, 1024) Private tag data                    ST: 'RM NEUROCHIRURGIA RO'
# (07a3, 1034) [Tamar Study Age]                   SH: '652'
# (07a3, 1055) [Unknown]                           SH: 'N'
# (07a3, 105c) Private tag data                    ST: '0'
# (07a3, 108f) Private tag data                    CS: 'N'
# (07a3, 1099) [Unknown]                           CS: 'N'
# (07a3, 109c) [Unknown]                           CS: 'N'
# (07a3, 10b9) Private tag data                    CS: 'N'
# (07a3, 10bb) Private tag data                    CS: 'N'
# (07a3, 10c0)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10ca)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a3, 10cb)  Private tag data   1 item(s) ----
#    (07a3, 0010) Private Creator                     LO: 'ELSCINT1'
#    (07a3, 10c1) Private tag data                    LO: 'opbgpacs'
#    (07a3, 10c2) Private tag data                    CS: 'FAST_NET'
#    (07a3, 10c3) Private tag data                    CS: 'REGULAR_CON'
#    (07a3, 10c4) Private tag data                    LO: '172.16.91.40'
#    (07a3, 10c5) Private tag data                    LO: '2104'
#    (07a3, 10c8) Private tag data                    AE: 'opbgpacsFIR'
#    (07a3, 10c9) Private tag data                    CS: 'N'
#    (07a3, 10cc) Private tag data                    LO: '1.0.0.0'
#    ---------
# (07a5, 0010) Private Creator                     LO: 'ELSCINT1'
# (07a5, 1054) Private tag data                    DT: '20150905153900.000000'
# (07a5, 1056) Private tag data                    CS: 'N'
# (07a5, 1059) Private tag data                    IS: '19'
# (07a5, 10c8) Private tag data                    CS: 'Y'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes
# SEPARATOR

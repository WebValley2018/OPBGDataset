# %%
import os
import pydicom as pd
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

PATH = "/Users/riccardobusetti/Desktop/tmp_processed/pa001/st000/se000"

print("ImagePositionPatient")

for file in os.listdir(PATH):
    dicom = pd.dcmread(os.path.join(PATH, file))
    print(dicom)
# Out:
# ImagePositionPatient
# (0008, 0005) Specific Character Set              CS: 'ISO 2022 IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20111119'
# (0008, 0013) Instance Creation Time              TM: '123508.296000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.67592182112743622478480346569375003812
# (0008, 0020) Study Date                          DA: '20111119'
# (0008, 0021) Series Date                         DA: '20111119'
# (0008, 0022) Acquisition Date                    DA: '20111119'
# (0008, 0023) Content Date                        DA: '20111119'
# (0008, 0030) Study Time                          TM: '121525.625000'
# (0008, 0031) Series Time                         TM: '123508.250000'
# (0008, 0032) Acquisition Time                    TM: '123443.705000'
# ...
